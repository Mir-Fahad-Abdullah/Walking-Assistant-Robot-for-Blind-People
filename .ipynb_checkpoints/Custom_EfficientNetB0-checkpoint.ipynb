# %% [markdown]
# # Import Libraries

# %%
import os
import numpy as np
import tensorflow as tf
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Input, Dense, Reshape, GlobalAveragePooling2D, Conv2D, UpSampling2D, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.losses import binary_crossentropy

# %% [markdown]
# # Configuration

# %%
IMG_SIZE = 320
BATCH_SIZE = 8
EPOCHS = 50
MAX_BOXES = 10

# %% [markdown]
# # Directory paths

# %%
base_dir = "Object-detection-dataset"
train_dir = os.path.join(base_dir, "train")
valid_dir = os.path.join(base_dir, "valid")

# %% [markdown]
# # Extract Class Labels

# %%
def extract_labels(directory):
    labels = set()
    for file in os.listdir(directory):
        if file.endswith(".xml"):
            tree = ET.parse(os.path.join(directory, file))
            for obj in tree.findall("object"):
                labels.add(obj.find("name").text)
    return sorted(list(labels))

label_list = extract_labels(train_dir)
label_map = {name: idx for idx, name in enumerate(label_list)}
NUM_CLASSES = len(label_list)
print("Detected Classes:", label_map)
# Out:
# Detected Classes: {'aeroplane': 0, 'apple': 1, 'backpack': 2, 'banana': 3, 'baseball bat': 4, 'baseball glove': 5, 'bear': 6, 'bed': 7, 'bench': 8, 'bicycle': 9, 'bird': 10, 'boat': 11, 'book': 12, 'bottle': 13, 'bowl': 14, 'broccoli': 15, 'bus': 16, 'cake': 17, 'car': 18, 'carrot': 19, 'cat': 20, 'cell phone': 21, 'chair': 22, 'clock': 23, 'cow': 24, 'cup': 25, 'diningtable': 26, 'dog': 27, 'donut': 28, 'elephant': 29, 'fire hydrant': 30, 'fork': 31, 'frisbee': 32, 'giraffe': 33, 'hair drier': 34, 'handbag': 35, 'horse': 36, 'hot dog': 37, 'keyboard': 38, 'kite': 39, 'knife': 40, 'laptop': 41, 'microwave': 42, 'motorbike': 43, 'mouse': 44, 'orange': 45, 'oven': 46, 'parking meter': 47, 'person': 48, 'pizza': 49, 'pottedplant': 50, 'refrigerator': 51, 'remote': 52, 'sandwich': 53, 'scissors': 54, 'sheep': 55, 'sink': 56, 'skateboard': 57, 'skis': 58, 'snowboard': 59, 'sofa': 60, 'spoon': 61, 'sports ball': 62, 'stop sign': 63, 'suitcase': 64, 'surfboard': 65, 'teddy bear': 66, 'tennis racket': 67, 'tie': 68, 'toaster': 69, 'toilet': 70, 'toothbrush': 71, 'traffic light': 72, 'train': 73, 'truck': 74, 'tvmonitor': 75, 'umbrella': 76, 'vase': 77, 'wine glass': 78, 'zebra': 79}

# %% [markdown]
# # Parse Pascal VOC Annotations

# %%
def parse_annotation(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()
    boxes, classes = [], []
    for obj in root.findall('object'):
        cls = obj.find('name').text
        bbox = obj.find('bndbox')
        xmin = float(bbox.find('xmin').text)
        ymin = float(bbox.find('ymin').text)
        xmax = float(bbox.find('xmax').text)
        ymax = float(bbox.find('ymax').text)
        boxes.append([xmin, ymin, xmax, ymax])
        classes.append(label_map[cls])
    return boxes, classes

# %% [markdown]
# # Load Dataset and Apply Padding

# %%
def load_dataset(image_dir):
    image_paths, box_list, class_list = [], [], []
    for fname in os.listdir(image_dir):
        if fname.endswith(".jpg") or fname.endswith(".png"):
            xml = os.path.join(image_dir, os.path.splitext(fname)[0] + ".xml")
            if os.path.exists(xml):
                boxes, labels = parse_annotation(xml)
                image_paths.append(os.path.join(image_dir, fname))
                box_list.append(boxes)
                class_list.append(labels)
    return image_paths, box_list, class_list

train_imgs, train_boxes, train_labels = load_dataset(train_dir)
val_imgs, val_boxes, val_labels = load_dataset(valid_dir)

# %% [markdown]
# # Pad Boxes and Labels

# %%
def pad_boxes_list(boxes_list):
    padded = []
    for boxes in boxes_list:
        b = np.array(boxes, dtype=np.float32)
        if b.ndim != 2 or b.shape[0] == 0:
            b = np.zeros((MAX_BOXES, 4), dtype=np.float32)
        elif len(b) > MAX_BOXES:
            b = b[:MAX_BOXES]
        else:
            pad_len = MAX_BOXES - len(b)
            b = np.pad(b, [(0, pad_len), (0, 0)], mode='constant')
        padded.append(b)
    return np.array(padded)

def pad_labels_list(labels_list, num_classes):
    padded = []
    for labels in labels_list:
        if len(labels) == 0:
            one_hots = np.zeros((MAX_BOXES, num_classes), dtype=np.float32)
        else:
            one_hots = np.eye(num_classes)[labels]
            if len(one_hots) > MAX_BOXES:
                one_hots = one_hots[:MAX_BOXES]
            else:
                pad_len = MAX_BOXES - len(one_hots)
                one_hots = np.pad(one_hots, [(0, pad_len), (0, 0)], mode='constant')
        padded.append(one_hots)
    return np.array(padded)

padded_train_boxes = pad_boxes_list(train_boxes)
padded_train_labels = pad_labels_list(train_labels, NUM_CLASSES)

padded_val_boxes = pad_boxes_list(val_boxes)
padded_val_labels = pad_labels_list(val_labels, NUM_CLASSES)

# %% [markdown]
# # Create tf.data.Dataset

# %%
def preprocess(img_path, boxes, labels):
    image = tf.io.read_file(img_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = tf.cast(image, tf.float32) / 255.0
    boxes = boxes / [640.0, 480.0, 640.0, 480.0]  # normalize
    return image, (boxes, labels)

train_ds = tf.data.Dataset.from_tensor_slices((train_imgs, padded_train_boxes, padded_train_labels))
train_ds = train_ds.map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((val_imgs, padded_val_boxes, padded_val_labels))
val_ds = val_ds.map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # Build EfficientNet-based Detector

# %%
def build_detector():
    base = EfficientNetB0(input_shape=(IMG_SIZE, IMG_SIZE, 3), include_top=False, weights="imagenet")
    base.trainable = True

    # Extract features from intermediate layers for FPN
    c3 = base.get_layer("block4a_expand_activation").output
    c4 = base.get_layer("block6a_expand_activation").output
    c5 = base.output

    p5 = Conv2D(128, 1, padding="same")(c5)
    p4 = UpSampling2D()(p5)
    p4 = Concatenate()([p4, c4])
    p4 = Conv2D(128, 3, padding="same", activation="relu")(p4)

    p3 = UpSampling2D()(p4)
    p3 = Concatenate()([p3, c3])
    p3 = Conv2D(128, 3, padding="same", activation="relu")(p3)

    x = GlobalAveragePooling2D()(p3)
    bbox_out = Dense(MAX_BOXES * 4, activation="sigmoid", name="bbox")(x)
    cls_out = Dense(MAX_BOXES * NUM_CLASSES, activation="sigmoid", name="class")(x)
    bbox_out = Reshape((MAX_BOXES, 4))(bbox_out)
    cls_out = Reshape((MAX_BOXES, NUM_CLASSES))(cls_out)

    return Model(inputs=base.input, outputs=[bbox_out, cls_out])

model = build_detector()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 320, 320, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 320, 320, 3)  0           ['input_2[0][0]']
#
#  normalization_1 (Normalization  (None, 320, 320, 3)  7          ['rescaling_1[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 321, 321, 3)  0           ['normalization_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 160, 160, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 160, 160, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 160, 160, 32  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 160, 160, 32  288        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 160, 160, 32  128        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 160, 160, 32  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 32)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 160, 160, 32  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 160, 160, 16  512         ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 160, 160, 16  64         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block2a_expand_conv (Conv2D)   (None, 160, 160, 96  1536        ['block1a_project_bn[0][0]']
#                                 )
#
#  block2a_expand_bn (BatchNormal  (None, 160, 160, 96  384        ['block2a_expand_conv[0][0]']
#  ization)                       )
#
#  block2a_expand_activation (Act  (None, 160, 160, 96  0          ['block2a_expand_bn[0][0]']
#  ivation)                       )
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 161, 161, 96  0          ['block2a_expand_activation[0][0]
#  g2D)                           )                                ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 80, 80, 96)  864         ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 80, 80, 96)  384         ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 80, 80, 96)  0           ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 96)          0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 96)     0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 4)      388         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 96)     480         ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 80, 80, 96)   0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 80, 80, 24)   2304        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 80, 80, 24)  96          ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 80, 80, 144)  3456        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 80, 80, 144)  576        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 80, 80, 144)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 80, 80, 144)  1296       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 80, 80, 144)  576        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 80, 80, 144)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 144)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 80, 80, 144)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 80, 80, 24)   3456        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 80, 80, 24)  96          ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 80, 80, 24)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 80, 80, 24)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 80, 80, 144)  3456        ['block2b_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 80, 80, 144)  576        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 80, 80, 144)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 83, 83, 144)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 40, 40, 144)  3600       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 40, 40, 144)  576        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 40, 40, 144)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 144)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 40, 40, 144)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 40, 40, 40)   5760        ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 40, 40, 40)  160         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 40, 40, 240)  9600        ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 40, 40, 240)  960        ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 40, 40, 240)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 40, 40, 240)  6000       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 40, 40, 240)  960        ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 40, 40, 240)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 240)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 40, 40, 240)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 40, 40, 40)   9600        ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 40, 40, 40)  160         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 40, 40, 40)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 40, 40, 40)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 40, 40, 240)  9600        ['block3b_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 40, 40, 240)  960        ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 40, 40, 240)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 41, 41, 240)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 20, 20, 240)  2160       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 20, 20, 240)  960        ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 20, 20, 240)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 240)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 240)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 10)     2410        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 240)    2640        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 20, 20, 240)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 20, 20, 80)   19200       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 20, 20, 80)  320         ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 20, 20, 480)  38400       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 20, 20, 480)  1920       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 20, 20, 480)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 20, 20, 480)  4320       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 20, 20, 480)  1920       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 20, 20, 480)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 480)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 20, 20, 480)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 20, 20, 80)   38400       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 20, 20, 80)  320         ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 20, 20, 80)   0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 20, 20, 80)   0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 20, 20, 480)  38400       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 20, 20, 480)  1920       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 20, 20, 480)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 20, 20, 480)  4320       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 20, 20, 480)  1920       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 20, 20, 480)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 480)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 20, 20, 480)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 20, 20, 80)   38400       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 20, 20, 80)  320         ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 20, 20, 80)   0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 20, 20, 80)   0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 20, 20, 480)  38400       ['block4c_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 20, 20, 480)  1920       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 20, 20, 480)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv (DepthwiseConv2  (None, 20, 20, 480)  12000      ['block5a_expand_activation[0][0]
#  D)                                                              ']
#
#  block5a_bn (BatchNormalization  (None, 20, 20, 480)  1920       ['block5a_dwconv[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 20, 20, 480)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 480)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 20, 20, 480)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 20, 20, 112)  53760       ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 20, 20, 112)  448        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 20, 20, 672)  75264       ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 20, 20, 672)  2688       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 20, 20, 672)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv (DepthwiseConv2  (None, 20, 20, 672)  16800      ['block5b_expand_activation[0][0]
#  D)                                                              ']
#
#  block5b_bn (BatchNormalization  (None, 20, 20, 672)  2688       ['block5b_dwconv[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 20, 20, 672)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 672)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 20, 20, 672)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 20, 20, 112)  75264       ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 20, 20, 112)  448        ['block5b_project_conv[0][0]']
#  lization)
#
#  block5b_drop (Dropout)         (None, 20, 20, 112)  0           ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)              (None, 20, 20, 112)  0           ['block5b_drop[0][0]',
#                                                                   'block5a_project_bn[0][0]']
#
#  block5c_expand_conv (Conv2D)   (None, 20, 20, 672)  75264       ['block5b_add[0][0]']
#
#  block5c_expand_bn (BatchNormal  (None, 20, 20, 672)  2688       ['block5c_expand_conv[0][0]']
#  ization)
#
#  block5c_expand_activation (Act  (None, 20, 20, 672)  0          ['block5c_expand_bn[0][0]']
#  ivation)
#
#  block5c_dwconv (DepthwiseConv2  (None, 20, 20, 672)  16800      ['block5c_expand_activation[0][0]
#  D)                                                              ']
#
#  block5c_bn (BatchNormalization  (None, 20, 20, 672)  2688       ['block5c_dwconv[0][0]']
#  )
#
#  block5c_activation (Activation  (None, 20, 20, 672)  0          ['block5c_bn[0][0]']
#  )
#
#  block5c_se_squeeze (GlobalAver  (None, 672)         0           ['block5c_activation[0][0]']
#  agePooling2D)
#
#  block5c_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block5c_se_squeeze[0][0]']
#
#  block5c_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5c_se_reshape[0][0]']
#
#  block5c_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5c_se_reduce[0][0]']
#
#  block5c_se_excite (Multiply)   (None, 20, 20, 672)  0           ['block5c_activation[0][0]',
#                                                                   'block5c_se_expand[0][0]']
#
#  block5c_project_conv (Conv2D)  (None, 20, 20, 112)  75264       ['block5c_se_excite[0][0]']
#
#  block5c_project_bn (BatchNorma  (None, 20, 20, 112)  448        ['block5c_project_conv[0][0]']
#  lization)
#
#  block5c_drop (Dropout)         (None, 20, 20, 112)  0           ['block5c_project_bn[0][0]']
#
#  block5c_add (Add)              (None, 20, 20, 112)  0           ['block5c_drop[0][0]',
#                                                                   'block5b_add[0][0]']
#
#  block6a_expand_conv (Conv2D)   (None, 20, 20, 672)  75264       ['block5c_add[0][0]']
#
#  block6a_expand_bn (BatchNormal  (None, 20, 20, 672)  2688       ['block6a_expand_conv[0][0]']
#  ization)
#
#  block6a_expand_activation (Act  (None, 20, 20, 672)  0          ['block6a_expand_bn[0][0]']
#  ivation)
#
#  block6a_dwconv_pad (ZeroPaddin  (None, 23, 23, 672)  0          ['block6a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block6a_dwconv (DepthwiseConv2  (None, 10, 10, 672)  16800      ['block6a_dwconv_pad[0][0]']
#  D)
#
#  block6a_bn (BatchNormalization  (None, 10, 10, 672)  2688       ['block6a_dwconv[0][0]']
#  )
#
#  block6a_activation (Activation  (None, 10, 10, 672)  0          ['block6a_bn[0][0]']
#  )
#
#  block6a_se_squeeze (GlobalAver  (None, 672)         0           ['block6a_activation[0][0]']
#  agePooling2D)
#
#  block6a_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block6a_se_squeeze[0][0]']
#
#  block6a_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block6a_se_reshape[0][0]']
#
#  block6a_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block6a_se_reduce[0][0]']
#
#  block6a_se_excite (Multiply)   (None, 10, 10, 672)  0           ['block6a_activation[0][0]',
#                                                                   'block6a_se_expand[0][0]']
#
#  block6a_project_conv (Conv2D)  (None, 10, 10, 192)  129024      ['block6a_se_excite[0][0]']
#
#  block6a_project_bn (BatchNorma  (None, 10, 10, 192)  768        ['block6a_project_conv[0][0]']
#  lization)
#
#  block6b_expand_conv (Conv2D)   (None, 10, 10, 1152  221184      ['block6a_project_bn[0][0]']
#                                 )
#
#  block6b_expand_bn (BatchNormal  (None, 10, 10, 1152  4608       ['block6b_expand_conv[0][0]']
#  ization)                       )
#
#  block6b_expand_activation (Act  (None, 10, 10, 1152  0          ['block6b_expand_bn[0][0]']
#  ivation)                       )
#
#  block6b_dwconv (DepthwiseConv2  (None, 10, 10, 1152  28800      ['block6b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6b_bn (BatchNormalization  (None, 10, 10, 1152  4608       ['block6b_dwconv[0][0]']
#  )                              )
#
#  block6b_activation (Activation  (None, 10, 10, 1152  0          ['block6b_bn[0][0]']
#  )                              )
#
# ...
#  block6b_add (Add)              (None, 10, 10, 192)  0           ['block6b_drop[0][0]',
#                                                                   'block6a_project_bn[0][0]']
#
#  block6c_expand_conv (Conv2D)   (None, 10, 10, 1152  221184      ['block6b_add[0][0]']
#                                 )
#
#  block6c_expand_bn (BatchNormal  (None, 10, 10, 1152  4608       ['block6c_expand_conv[0][0]']
#  ization)                       )
#
#  block6c_expand_activation (Act  (None, 10, 10, 1152  0          ['block6c_expand_bn[0][0]']
#  ivation)                       )
#
#  block6c_dwconv (DepthwiseConv2  (None, 10, 10, 1152  28800      ['block6c_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6c_bn (BatchNormalization  (None, 10, 10, 1152  4608       ['block6c_dwconv[0][0]']
#  )                              )
#
#  block6c_activation (Activation  (None, 10, 10, 1152  0          ['block6c_bn[0][0]']
#  )                              )
#
#  block6c_se_squeeze (GlobalAver  (None, 1152)        0           ['block6c_activation[0][0]']
#  agePooling2D)
#
#  block6c_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6c_se_squeeze[0][0]']
#
#  block6c_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6c_se_reshape[0][0]']
#
#  block6c_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6c_se_reduce[0][0]']
#
#  block6c_se_excite (Multiply)   (None, 10, 10, 1152  0           ['block6c_activation[0][0]',
#                                 )                                 'block6c_se_expand[0][0]']
#
#  block6c_project_conv (Conv2D)  (None, 10, 10, 192)  221184      ['block6c_se_excite[0][0]']
#
#  block6c_project_bn (BatchNorma  (None, 10, 10, 192)  768        ['block6c_project_conv[0][0]']
#  lization)
#
#  block6c_drop (Dropout)         (None, 10, 10, 192)  0           ['block6c_project_bn[0][0]']
#
#  block6c_add (Add)              (None, 10, 10, 192)  0           ['block6c_drop[0][0]',
#                                                                   'block6b_add[0][0]']
#
#  block6d_expand_conv (Conv2D)   (None, 10, 10, 1152  221184      ['block6c_add[0][0]']
#                                 )
#
#  block6d_expand_bn (BatchNormal  (None, 10, 10, 1152  4608       ['block6d_expand_conv[0][0]']
#  ization)                       )
#
#  block6d_expand_activation (Act  (None, 10, 10, 1152  0          ['block6d_expand_bn[0][0]']
#  ivation)                       )
#
#  block6d_dwconv (DepthwiseConv2  (None, 10, 10, 1152  28800      ['block6d_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6d_bn (BatchNormalization  (None, 10, 10, 1152  4608       ['block6d_dwconv[0][0]']
#  )                              )
#
#  block6d_activation (Activation  (None, 10, 10, 1152  0          ['block6d_bn[0][0]']
#  )                              )
#
#  block6d_se_squeeze (GlobalAver  (None, 1152)        0           ['block6d_activation[0][0]']
#  agePooling2D)
#
#  block6d_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block6d_se_squeeze[0][0]']
#
#  block6d_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block6d_se_reshape[0][0]']
#
#  block6d_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block6d_se_reduce[0][0]']
#
#  block6d_se_excite (Multiply)   (None, 10, 10, 1152  0           ['block6d_activation[0][0]',
#                                 )                                 'block6d_se_expand[0][0]']
#
#  block6d_project_conv (Conv2D)  (None, 10, 10, 192)  221184      ['block6d_se_excite[0][0]']
#
#  block6d_project_bn (BatchNorma  (None, 10, 10, 192)  768        ['block6d_project_conv[0][0]']
#  lization)
#
#  block6d_drop (Dropout)         (None, 10, 10, 192)  0           ['block6d_project_bn[0][0]']
#
#  block6d_add (Add)              (None, 10, 10, 192)  0           ['block6d_drop[0][0]',
#                                                                   'block6c_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 10, 10, 1152  221184      ['block6d_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 10, 10, 1152  4608       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 10, 10, 1152  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 10, 10, 1152  10368      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 10, 10, 1152  4608       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 10, 10, 1152  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1152)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1152)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 48)     55344       ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1152)   56448       ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 10, 10, 1152  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 10, 10, 320)  368640      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 10, 10, 320)  1280       ['block7a_project_conv[0][0]']
#  lization)
#
#  top_conv (Conv2D)              (None, 10, 10, 1280  409600      ['block7a_project_bn[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 10, 10, 1280  5120        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 10, 10, 1280  0           ['top_bn[0][0]']
#                                 )
#
#  conv2d (Conv2D)                (None, 10, 10, 128)  163968      ['top_activation[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 20, 20, 128)  0           ['conv2d[0][0]']
#
#  concatenate (Concatenate)      (None, 20, 20, 800)  0           ['up_sampling2d[0][0]',
#                                                                   'block6a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_1 (Conv2D)              (None, 20, 20, 128)  921728      ['concatenate[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 40, 40, 128)  0          ['conv2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 40, 40, 368)  0           ['up_sampling2d_1[0][0]',
#                                                                   'block4a_expand_activation[0][0]
#                                                                  ']
#
#  conv2d_2 (Conv2D)              (None, 40, 40, 128)  424064      ['concatenate_1[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['conv2d_2[0][0]']
#  obalAveragePooling2D)
#
#  bbox (Dense)                   (None, 40)           5160        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  class (Dense)                  (None, 800)          103200      ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  reshape_2 (Reshape)            (None, 10, 4)        0           ['bbox[0][0]']
#
#  reshape_3 (Reshape)            (None, 10, 80)       0           ['class[0][0]']
#
# ==================================================================================================
# Total params: 5,667,691
# Trainable params: 5,625,668
# Non-trainable params: 42,023
# __________________________________________________________________________________________________

# %% [markdown]
# # Loss Functions

# %%
def ciou_loss(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))

def focal_loss(y_true, y_pred, gamma=2.0, alpha=0.25):
    bce = binary_crossentropy(y_true, y_pred)
    pt = tf.exp(-bce)
    return tf.reduce_mean(alpha * (1 - pt) ** gamma * bce)

def total_loss(y_true, y_pred):
    return ciou_loss(y_true[0], y_pred[0]) + focal_loss(y_true[1], y_pred[1])

# %% [markdown]
# # Training

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), loss=total_loss)
history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS)

# %% [markdown]
# # Plot Loss

# %%
plt.plot(history.history['loss'], label='Loss')
plt.title("Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Export TFLite (float16)

# %%
model.save("efficientnet_detector")
converter = tf.lite.TFLiteConverter.from_saved_model("efficientnet_detector")
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_types = [tf.float16]
tflite_model = converter.convert()
with open("detector_float16.tflite", "wb") as f:
    f.write(tflite_model)
print("\u2705 Exported float16 TFLite model for Jetson Nano.")
